# %% [markdown]
# # Two-Sample Kolmogorov-Smirnov Test

# %%
import pandas as pd
from scipy.stats import ks_2samp

# Load the dataset
df = pd.read_csv('Final_Dataset.csv')

# List of variables you want to compare
variables = [
    'time_accel', 'accel_x_max', 'accel_y_max', 'accel_z_max', 'accel_inclination_max', 
    'accel_zscore_x_max', 'accel_zscore_y_max', 'accel_zscore_z_max', 'accel_zscore_inclination_max', 
    'accel_x_min', 'accel_y_min', 'accel_z_min', 'accel_inclination_min', 
    'accel_zscore_x_min', 'accel_zscore_y_min', 'accel_zscore_z_min', 'accel_zscore_inclination_min', 
    'accel_x_sd', 'accel_y_sd', 'accel_z_sd', 'accel_inclination_sd', 
    'accel_zscore_x_sd', 'accel_zscore_y_sd', 'accel_zscore_z_sd', 'accel_zscore_inclination_sd', 
    'accel_x_mean', 'accel_y_mean', 'accel_z_mean', 'accel_inclination_mean', 
    'accel_zscore_x_mean', 'accel_zscore_y_mean', 'accel_zscore_z_mean', 'accel_zscore_inclination_mean', 
    'accel_x_dominant_freq', 'accel_y_dominant_freq', 'accel_z_dominant_freq', 'accel_inclination_dominant_freq', 
    'accel_zscore_x_dominant_freq', 'accel_zscore_y_dominant_freq', 'accel_zscore_z_dominant_freq', 'accel_zscore_inclination_dominant_freq', 
    'accel_x_avg_weigh_freq', 'accel_y_avg_weigh_freq', 'accel_z_avg_weigh_freq', 'accel_inclination_avg_weigh_freq', 
    'accel_zscore_x_avg_weigh_freq', 'accel_zscore_y_avg_weigh_freq', 'accel_zscore_z_avg_weigh_freq', 'accel_zscore_inclination_avg_weigh_freq', 
    'time_linaccel', 'linaccel_x_max', 'linaccel_y_max', 'linaccel_z_max', 
    'linaccel_zscore_x_max', 'linaccel_zscore_y_max', 'linaccel_zscore_z_max', 
    'linaccel_x_min', 'linaccel_y_min', 'linaccel_z_min', 
    'linaccel_zscore_x_min', 'linaccel_zscore_y_min', 'linaccel_zscore_z_min', 
    'linaccel_x_sd', 'linaccel_y_sd', 'linaccel_z_sd', 
    'linaccel_zscore_x_sd', 'linaccel_zscore_y_sd', 'linaccel_zscore_z_sd', 
    'linaccel_x_mean', 'linaccel_y_mean', 'linaccel_z_mean', 
    'linaccel_zscore_x_mean', 'linaccel_zscore_y_mean', 'linaccel_zscore_z_mean', 
    'time_mergedpost', 'gyro_x_max', 'gyro_y_max', 'gyro_z_max', 
    'gyro_zscore_x_max', 'gyro_zscore_y_max', 'gyro_zscore_z_max', 
    'gyro_x_min', 'gyro_y_min', 'gyro_z_min', 
    'gyro_zscore_x_min', 'gyro_zscore_y_min', 'gyro_zscore_z_min', 
    'gyro_x_sd', 'gyro_y_sd', 'gyro_z_sd', 
    'gyro_zscore_x_sd', 'gyro_zscore_y_sd', 'gyro_zscore_z_sd', 
    'gyro_x_mean', 'gyro_y_mean', 'gyro_z_mean', 
    'gyro_zscore_x_mean', 'gyro_zscore_y_mean', 'gyro_zscore_z_mean', 
    'time_baro', 'baro_x', 'baro_zscore_x'
]

# Preparing to collect results
results = []

# Conduct the K-S test for each pair of variables
for i in range(len(variables)):
    for j in range(i + 1, len(variables)):
        var1 = variables[i]
        var2 = variables[j]
        
        # Perform K-S test, ensuring no NaN values are included
        result = ks_2samp(df[var1].dropna(), df[var2].dropna())
        results.append((var1, var2, result.statistic, result.pvalue))

# Print the results sorted by p-value (most significant first)
results_sorted = sorted(results, key=lambda x: x[3])
for res in results_sorted:
    print(f"Variables: {res[0]} vs {res[1]}, K-S Statistic: {res[2]}, p-value: {res[3]}")
# Out:
# Variables: linaccel_zscore_x_min vs linaccel_z_sd, K-S Statistic: 0.715652128954629, p-value: 0.0
# Variables: linaccel_zscore_x_min vs linaccel_zscore_x_sd, K-S Statistic: 0.7276000319613456, p-value: 0.0
# Variables: linaccel_zscore_x_min vs linaccel_zscore_y_sd, K-S Statistic: 0.7268291995092994, p-value: 0.0
# Variables: linaccel_zscore_x_min vs linaccel_zscore_z_sd, K-S Statistic: 0.7268574006965693, p-value: 0.0
# Variables: linaccel_zscore_x_min vs linaccel_x_mean, K-S Statistic: 0.5052101693481296, p-value: 0.0
# Variables: linaccel_zscore_x_min vs linaccel_y_mean, K-S Statistic: 0.5736873522375292, p-value: 0.0
# Variables: linaccel_zscore_x_min vs linaccel_z_mean, K-S Statistic: 0.5386238760651824, p-value: 0.0
# Variables: linaccel_zscore_x_min vs linaccel_zscore_x_mean, K-S Statistic: 0.23834703441014865, p-value: 0.0
# Variables: linaccel_zscore_x_min vs linaccel_zscore_y_mean, K-S Statistic: 0.2833608294909216, p-value: 0.0
# Variables: linaccel_zscore_x_min vs linaccel_zscore_z_mean, K-S Statistic: 0.21813148333544846, p-value: 0.0
# Variables: linaccel_zscore_x_min vs time_mergedpost, K-S Statistic: 0.9872577635518455, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_x_max, K-S Statistic: 0.5955056707887402, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_y_max, K-S Statistic: 0.6074441733997001, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_z_max, K-S Statistic: 0.6227480176915448, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_zscore_x_max, K-S Statistic: 0.4222376100212366, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_zscore_y_max, K-S Statistic: 0.4760331293183582, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_zscore_z_max, K-S Statistic: 0.42651161530574355, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_x_min, K-S Statistic: 0.49910931250205637, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_y_min, K-S Statistic: 0.5035133979140523, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_z_min, K-S Statistic: 0.5576173756915166, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_zscore_x_min, K-S Statistic: 0.11979856790680382, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_zscore_y_min, K-S Statistic: 0.15066734595742287, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_zscore_z_min, K-S Statistic: 0.14645333743674643, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_x_sd, K-S Statistic: 0.7147872925450162, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_y_sd, K-S Statistic: 0.7147872925450162, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_z_sd, K-S Statistic: 0.7147731919513811, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_zscore_x_sd, K-S Statistic: 0.7178391853564509, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_zscore_y_sd, K-S Statistic: 0.7174383888589302, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_zscore_z_sd, K-S Statistic: 0.7188202470351593, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_x_mean, K-S Statistic: 0.5606208021357699, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_y_mean, K-S Statistic: 0.5701669040266595, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_z_mean, K-S Statistic: 0.5992000263211081, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_zscore_x_mean, K-S Statistic: 0.27914104557840824, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_zscore_y_mean, K-S Statistic: 0.3287890694663676, p-value: 0.0
# Variables: linaccel_zscore_x_min vs gyro_zscore_z_mean, K-S Statistic: 0.29445303336161277, p-value: 0.0
# Variables: linaccel_zscore_x_min vs time_baro, K-S Statistic: 0.9857160986477531, p-value: 0.0
# Variables: linaccel_zscore_x_min vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_zscore_x_min vs baro_zscore_x, K-S Statistic: 0.2900257100823944, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_x_sd, K-S Statistic: 0.7132597282345586, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_y_sd, K-S Statistic: 0.7131610240791137, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_z_sd, K-S Statistic: 0.7136874462414868, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_zscore_x_sd, K-S Statistic: 0.7307585649355838, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_zscore_y_sd, K-S Statistic: 0.729921929713241, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_zscore_z_sd, K-S Statistic: 0.7296164168511495, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_x_mean, K-S Statistic: 0.4828372274472755, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_y_mean, K-S Statistic: 0.5580920956772281, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_z_mean, K-S Statistic: 0.526182452281241, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_zscore_x_mean, K-S Statistic: 0.22794079630752462, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_zscore_y_mean, K-S Statistic: 0.2697114548522493, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_zscore_z_mean, K-S Statistic: 0.1948937050249816, p-value: 0.0
# Variables: linaccel_zscore_y_min vs time_mergedpost, K-S Statistic: 0.9887947282580597, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_x_max, K-S Statistic: 0.581076063302265, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_y_max, K-S Statistic: 0.5949416470433405, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_z_max, K-S Statistic: 0.6098412743176488, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_zscore_x_max, K-S Statistic: 0.40762665422195765, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_zscore_y_max, K-S Statistic: 0.46386508217253736, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_zscore_z_max, K-S Statistic: 0.4130592839206681, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_x_min, K-S Statistic: 0.4770653844526855, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_y_min, K-S Statistic: 0.483199142683907, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_z_min, K-S Statistic: 0.5381303552879576, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_zscore_x_min, K-S Statistic: 0.09492162371218121, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_zscore_y_min, K-S Statistic: 0.12595465293024777, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_zscore_z_min, K-S Statistic: 0.12148717818985771, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_x_sd, K-S Statistic: 0.7123948918249459, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_y_sd, K-S Statistic: 0.7123901916270675, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_z_sd, K-S Statistic: 0.7123854914291892, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_zscore_x_sd, K-S Statistic: 0.7166781011352049, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_zscore_y_sd, K-S Statistic: 0.7161439027206541, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_zscore_z_sd, K-S Statistic: 0.7180792277090207, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_x_mean, K-S Statistic: 0.5419892177460671, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_y_mean, K-S Statistic: 0.5536739096715972, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_z_mean, K-S Statistic: 0.583689373322617, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_zscore_x_mean, K-S Statistic: 0.255871732631661, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_zscore_y_mean, K-S Statistic: 0.30653154294470875, p-value: 0.0
# Variables: linaccel_zscore_y_min vs gyro_zscore_z_mean, K-S Statistic: 0.27176648338160014, p-value: 0.0
# Variables: linaccel_zscore_y_min vs time_baro, K-S Statistic: 0.9872483631560889, p-value: 0.0
# Variables: linaccel_zscore_y_min vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_zscore_y_min vs baro_zscore_x, K-S Statistic: 0.3167510352185827, p-value: 0.0
# Variables: linaccel_zscore_z_min vs linaccel_x_sd, K-S Statistic: 0.7500340764346178, p-value: 0.0
# Variables: linaccel_zscore_z_min vs linaccel_y_sd, K-S Statistic: 0.7499306720812946, p-value: 0.0
# Variables: linaccel_zscore_z_min vs linaccel_z_sd, K-S Statistic: 0.7502314847455078, p-value: 0.0
# Variables: linaccel_zscore_z_min vs linaccel_zscore_x_sd, K-S Statistic: 0.7603087089966488, p-value: 0.0
# Variables: linaccel_zscore_z_min vs linaccel_zscore_y_sd, K-S Statistic: 0.7595989791170209, p-value: 0.0
# Variables: linaccel_zscore_z_min vs linaccel_zscore_z_sd, K-S Statistic: 0.7597305846576141, p-value: 0.0
# Variables: linaccel_zscore_z_min vs linaccel_x_mean, K-S Statistic: 0.5407812668913361, p-value: 0.0
# Variables: linaccel_zscore_z_min vs linaccel_y_mean, K-S Statistic: 0.6110116235893531, p-value: 0.0
# Variables: linaccel_zscore_z_min vs linaccel_z_mean, K-S Statistic: 0.575887044844588, p-value: 0.0
# Variables: linaccel_zscore_z_min vs linaccel_zscore_x_mean, K-S Statistic: 0.27524358775504454, p-value: 0.0
# Variables: linaccel_zscore_z_min vs linaccel_zscore_y_mean, K-S Statistic: 0.32043129015731564, p-value: 0.0
# Variables: linaccel_zscore_z_min vs linaccel_zscore_z_mean, K-S Statistic: 0.25301165179054036, p-value: 0.0
# Variables: linaccel_zscore_z_min vs time_mergedpost, K-S Statistic: 0.9875256748309104, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_x_max, K-S Statistic: 0.6327782399639025, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_y_max, K-S Statistic: 0.6444253303064059, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_z_max, K-S Statistic: 0.6599359833048972, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_zscore_x_max, K-S Statistic: 0.4595103145416971, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_zscore_y_max, K-S Statistic: 0.5130576704956187, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_zscore_z_max, K-S Statistic: 0.46382658471954924, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_x_min, K-S Statistic: 0.5348919189497877, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_y_min, K-S Statistic: 0.5400010340435333, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_z_min, K-S Statistic: 0.5944716272555074, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_zscore_x_min, K-S Statistic: 0.15009359773757502, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_zscore_y_min, K-S Statistic: 0.18055653571802327, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_zscore_z_min, K-S Statistic: 0.17639209855490767, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_x_sd, K-S Statistic: 0.7494371513040698, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_y_sd, K-S Statistic: 0.7494418515019482, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_z_sd, K-S Statistic: 0.7494230507104349, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_zscore_x_sd, K-S Statistic: 0.7519123101170121, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_zscore_y_sd, K-S Statistic: 0.7516371639669623, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_zscore_z_sd, K-S Statistic: 0.7528120780912468, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_x_mean, K-S Statistic: 0.5973951503358291, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_y_mean, K-S Statistic: 0.6074629741912134, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_z_mean, K-S Statistic: 0.6365383982665671, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_zscore_x_mean, K-S Statistic: 0.31396841743498366, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_zscore_y_mean, K-S Statistic: 0.36448280450934084, p-value: 0.0
# Variables: linaccel_zscore_z_min vs gyro_zscore_z_mean, K-S Statistic: 0.3296329946523911, p-value: 0.0
# Variables: linaccel_zscore_z_min vs time_baro, K-S Statistic: 0.9859793097289395, p-value: 0.0
# Variables: linaccel_zscore_z_min vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_zscore_z_min vs baro_zscore_x, K-S Statistic: 0.2954638390276231, p-value: 0.0
# Variables: linaccel_x_sd vs linaccel_z_sd, K-S Statistic: 0.12582899740079057, p-value: 0.0
# Variables: linaccel_x_sd vs linaccel_zscore_x_sd, K-S Statistic: 0.7105007120799787, p-value: 0.0
# Variables: linaccel_x_sd vs linaccel_zscore_y_sd, K-S Statistic: 0.7145851840362479, p-value: 0.0
# Variables: linaccel_x_sd vs linaccel_zscore_z_sd, K-S Statistic: 0.703770028718209, p-value: 0.0
# Variables: linaccel_x_sd vs linaccel_x_mean, K-S Statistic: 0.5814332783410182, p-value: 0.0
# Variables: linaccel_x_sd vs linaccel_y_mean, K-S Statistic: 0.36576469869381506, p-value: 0.0
# Variables: linaccel_x_sd vs linaccel_z_mean, K-S Statistic: 0.5178631020365958, p-value: 0.0
# Variables: linaccel_x_sd vs linaccel_zscore_x_mean, K-S Statistic: 0.4864798808029818, p-value: 0.0
# Variables: linaccel_x_sd vs linaccel_zscore_y_mean, K-S Statistic: 0.44444601117707055, p-value: 0.0
# Variables: linaccel_x_sd vs linaccel_zscore_z_mean, K-S Statistic: 0.5234845386990792, p-value: 0.0
# Variables: linaccel_x_sd vs time_mergedpost, K-S Statistic: 0.9967897648491001, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_x_max, K-S Statistic: 0.36239465681505195, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_y_max, K-S Statistic: 0.35005663738443393, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_z_max, K-S Statistic: 0.41862782423140016, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_zscore_x_max, K-S Statistic: 0.4067171307495415, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_zscore_y_max, K-S Statistic: 0.4209950334754394, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_zscore_z_max, K-S Statistic: 0.40909674416856595, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_x_min, K-S Statistic: 0.7411977044233562, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_y_min, K-S Statistic: 0.7715797835088858, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_z_min, K-S Statistic: 0.7531550078258296, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_zscore_x_min, K-S Statistic: 0.7063283207043686, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_zscore_y_min, K-S Statistic: 0.7184772722309333, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_zscore_z_min, K-S Statistic: 0.6948480522717707, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_x_sd, K-S Statistic: 0.30764205173037784, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_y_sd, K-S Statistic: 0.3163421180031679, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_z_sd, K-S Statistic: 0.48693109979930155, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_zscore_x_sd, K-S Statistic: 0.4906833841420742, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_zscore_y_sd, K-S Statistic: 0.4750045099610273, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_zscore_z_sd, K-S Statistic: 0.5011451794100106, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_x_mean, K-S Statistic: 0.5677604027129542, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_y_mean, K-S Statistic: 0.5877926460703996, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_z_mean, K-S Statistic: 0.6055969956335162, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_zscore_x_mean, K-S Statistic: 0.5181145967832851, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_zscore_y_mean, K-S Statistic: 0.48682134819468725, p-value: 0.0
# Variables: linaccel_x_sd vs gyro_zscore_z_mean, K-S Statistic: 0.5026604467989612, p-value: 0.0
# Variables: linaccel_x_sd vs time_baro, K-S Statistic: 0.995238699549251, p-value: 0.0
# Variables: linaccel_x_sd vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_x_sd vs baro_zscore_x, K-S Statistic: 0.49506714232669197, p-value: 0.0
# Variables: linaccel_y_sd vs linaccel_z_sd, K-S Statistic: 0.16279135351598306, p-value: 0.0
# Variables: linaccel_y_sd vs linaccel_zscore_x_sd, K-S Statistic: 0.7373435421631251, p-value: 0.0
# Variables: linaccel_y_sd vs linaccel_zscore_y_sd, K-S Statistic: 0.7407511856249147, p-value: 0.0
# Variables: linaccel_y_sd vs linaccel_zscore_z_sd, K-S Statistic: 0.7304389514798573, p-value: 0.0
# Variables: linaccel_y_sd vs linaccel_x_mean, K-S Statistic: 0.5797130059175492, p-value: 0.0
# Variables: linaccel_y_sd vs linaccel_y_mean, K-S Statistic: 0.3972325234892389, p-value: 0.0
# Variables: linaccel_y_sd vs linaccel_z_mean, K-S Statistic: 0.538520471711859, p-value: 0.0
# Variables: linaccel_y_sd vs linaccel_zscore_x_mean, K-S Statistic: 0.4863952772411719, p-value: 0.0
# Variables: linaccel_y_sd vs linaccel_zscore_y_mean, K-S Statistic: 0.4443614076152606, p-value: 0.0
# Variables: linaccel_y_sd vs linaccel_zscore_z_mean, K-S Statistic: 0.5233717339499993, p-value: 0.0
# Variables: linaccel_y_sd vs time_mergedpost, K-S Statistic: 0.9969260705875718, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_x_max, K-S Statistic: 0.3538026950934634, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_y_max, K-S Statistic: 0.33705589005297126, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_z_max, K-S Statistic: 0.40306076885836895, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_zscore_x_max, K-S Statistic: 0.42135288051196046, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_zscore_y_max, K-S Statistic: 0.4394972497152877, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_zscore_z_max, K-S Statistic: 0.4255068800638651, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_x_min, K-S Statistic: 0.7377618597742964, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_y_min, K-S Statistic: 0.7678243254040995, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_z_min, K-S Statistic: 0.7477685810572625, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_zscore_x_min, K-S Statistic: 0.7061770532079715, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_zscore_y_min, K-S Statistic: 0.7181157877128151, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_zscore_z_min, K-S Statistic: 0.6947045732324928, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_x_sd, K-S Statistic: 0.27918705377496394, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_y_sd, K-S Statistic: 0.2881597315246972, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_z_sd, K-S Statistic: 0.4604031829740032, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_zscore_x_sd, K-S Statistic: 0.5241232472073571, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_zscore_y_sd, K-S Statistic: 0.5081179695322062, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_zscore_z_sd, K-S Statistic: 0.5363447755193491, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_x_mean, K-S Statistic: 0.5606537035209183, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_y_mean, K-S Statistic: 0.5797412071048191, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_z_mean, K-S Statistic: 0.5959333887956683, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_zscore_x_mean, K-S Statistic: 0.517940689461787, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_zscore_y_mean, K-S Statistic: 0.4864973668018574, p-value: 0.0
# Variables: linaccel_y_sd vs gyro_zscore_z_mean, K-S Statistic: 0.5023649988541763, p-value: 0.0
# Variables: linaccel_y_sd vs time_baro, K-S Statistic: 0.9953891058813575, p-value: 0.0
# Variables: linaccel_y_sd vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_y_sd vs baro_zscore_x, K-S Statistic: 0.4950577419309353, p-value: 0.0
# Variables: linaccel_z_sd vs linaccel_zscore_x_sd, K-S Statistic: 0.6046287548705801, p-value: 0.0
# Variables: linaccel_z_sd vs linaccel_zscore_y_sd, K-S Statistic: 0.610085684607322, p-value: 0.0
# Variables: linaccel_z_sd vs linaccel_zscore_z_sd, K-S Statistic: 0.598217684964537, p-value: 0.0
# Variables: linaccel_z_sd vs linaccel_x_mean, K-S Statistic: 0.5868996084735167, p-value: 0.0
# Variables: linaccel_z_sd vs linaccel_y_mean, K-S Statistic: 0.2497967164417622, p-value: 0.0
# Variables: linaccel_z_sd vs linaccel_z_mean, K-S Statistic: 0.42382624308483385, p-value: 0.0
# Variables: linaccel_z_sd vs linaccel_zscore_x_mean, K-S Statistic: 0.48682299524809997, p-value: 0.0
# Variables: linaccel_z_sd vs linaccel_zscore_y_mean, K-S Statistic: 0.44478442542431035, p-value: 0.0
# Variables: linaccel_z_sd vs linaccel_zscore_z_mean, K-S Statistic: 0.5238370535399541, p-value: 0.0
# Variables: linaccel_z_sd vs time_mergedpost, K-S Statistic: 0.9959390290331223, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_x_max, K-S Statistic: 0.38879566829763534, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_y_max, K-S Statistic: 0.3834280423205817, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_z_max, K-S Statistic: 0.45758776444488314, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_zscore_x_max, K-S Statistic: 0.33909990672521606, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_zscore_y_max, K-S Statistic: 0.34156882444940095, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_zscore_z_max, K-S Statistic: 0.332599614948504, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_x_min, K-S Statistic: 0.7506592027524359, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_y_min, K-S Statistic: 0.7810459820358437, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_z_min, K-S Statistic: 0.7654977274543258, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_zscore_x_min, K-S Statistic: 0.7071321283166829, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_zscore_y_min, K-S Statistic: 0.7196576861472082, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_zscore_z_min, K-S Statistic: 0.6954149673609346, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_x_sd, K-S Statistic: 0.38841965246736887, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_y_sd, K-S Statistic: 0.3965556949947593, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_z_sd, K-S Statistic: 0.5554270834802146, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_zscore_x_sd, K-S Statistic: 0.3707870967253931, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_zscore_y_sd, K-S Statistic: 0.35568132015218606, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_zscore_z_sd, K-S Statistic: 0.3771952649236997, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_x_mean, K-S Statistic: 0.586420188289927, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_y_mean, K-S Statistic: 0.6093900553213291, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_z_mean, K-S Statistic: 0.630070925985984, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_zscore_x_mean, K-S Statistic: 0.5190761068961333, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_zscore_y_mean, K-S Statistic: 0.4883674054457656, p-value: 0.0
# Variables: linaccel_z_sd vs gyro_zscore_z_mean, K-S Statistic: 0.5037021187613961, p-value: 0.0
# Variables: linaccel_z_sd vs time_baro, K-S Statistic: 0.9943973641290299, p-value: 0.0
# Variables: linaccel_z_sd vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_z_sd vs baro_zscore_x, K-S Statistic: 0.49506714232669197, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs linaccel_x_mean, K-S Statistic: 0.7528729959531297, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs linaccel_y_mean, K-S Statistic: 0.5464168041474546, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs linaccel_z_mean, K-S Statistic: 0.3087747994190555, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs linaccel_zscore_x_mean, K-S Statistic: 0.5029681749601658, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs linaccel_zscore_y_mean, K-S Statistic: 0.46414924068303276, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs linaccel_zscore_z_mean, K-S Statistic: 0.5418529120075956, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs time_mergedpost, K-S Statistic: 0.9859182071565213, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_x_max, K-S Statistic: 0.7136780458457301, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_y_max, K-S Statistic: 0.7331979676344375, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_z_max, K-S Statistic: 0.7940232283779147, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_zscore_x_max, K-S Statistic: 0.3622801096231023, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_zscore_y_max, K-S Statistic: 0.31798303628506164, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_zscore_z_max, K-S Statistic: 0.3508376152791253, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_x_min, K-S Statistic: 0.873865489737118, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_y_min, K-S Statistic: 0.8945980625784345, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_z_min, K-S Statistic: 0.9069595829984443, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_zscore_x_min, K-S Statistic: 0.7317388402478819, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_zscore_y_min, K-S Statistic: 0.7559957822226754, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_zscore_z_min, K-S Statistic: 0.7232267827084334, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_x_sd, K-S Statistic: 0.8350700564493765, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_y_sd, K-S Statistic: 0.8252983450603271, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_z_sd, K-S Statistic: 0.9062122515357897, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_zscore_x_sd, K-S Statistic: 0.24902990302914121, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_zscore_y_sd, K-S Statistic: 0.2596343243541486, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_zscore_z_sd, K-S Statistic: 0.28446225664117114, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_x_mean, K-S Statistic: 0.8126877141527657, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_y_mean, K-S Statistic: 0.8344731313188285, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_z_mean, K-S Statistic: 0.8661618654145339, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_zscore_x_mean, K-S Statistic: 0.5613310984201295, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_zscore_y_mean, K-S Statistic: 0.5585905727515452, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs gyro_zscore_z_mean, K-S Statistic: 0.5500642320898153, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs time_baro, K-S Statistic: 0.9843718420545505, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_zscore_x_sd vs baro_zscore_x, K-S Statistic: 0.4982585766860785, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs linaccel_x_mean, K-S Statistic: 0.7524875797271064, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs linaccel_y_mean, K-S Statistic: 0.5570909535291436, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs linaccel_z_mean, K-S Statistic: 0.31624811404560127, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs linaccel_zscore_x_mean, K-S Statistic: 0.5021738415187279, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs linaccel_zscore_y_mean, K-S Statistic: 0.46326090328402825, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs linaccel_zscore_z_mean, K-S Statistic: 0.5410632787640359, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs time_mergedpost, K-S Statistic: 0.98516147529811, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_x_max, K-S Statistic: 0.7150035016474193, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_y_max, K-S Statistic: 0.7338277941501338, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_z_max, K-S Statistic: 0.7945073487593828, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_zscore_x_max, K-S Statistic: 0.3613420259063177, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_zscore_y_max, K-S Statistic: 0.3178872717476735, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_zscore_z_max, K-S Statistic: 0.3497594106546916, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_x_min, K-S Statistic: 0.8730053535253834, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_y_min, K-S Statistic: 0.8932585061831103, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_z_min, K-S Statistic: 0.9058127347161316, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_zscore_x_min, K-S Statistic: 0.7306775310122617, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_zscore_y_min, K-S Statistic: 0.754841121073361, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_zscore_z_min, K-S Statistic: 0.7220757511995529, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_x_sd, K-S Statistic: 0.8353097665411714, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_y_sd, K-S Statistic: 0.8252607434773004, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_z_sd, K-S Statistic: 0.9055166222497968, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_zscore_x_sd, K-S Statistic: 0.25824658094161124, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_zscore_y_sd, K-S Statistic: 0.26728458383251563, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_zscore_z_sd, K-S Statistic: 0.29405640584019777, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_x_mean, K-S Statistic: 0.8121847929797844, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_y_mean, K-S Statistic: 0.8338809063861587, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_z_mean, K-S Statistic: 0.8655414392945944, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_zscore_x_mean, K-S Statistic: 0.5600044245107562, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_zscore_y_mean, K-S Statistic: 0.5580608165946898, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs gyro_zscore_z_mean, K-S Statistic: 0.5492301193356377, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs time_baro, K-S Statistic: 0.983610409998261, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_zscore_y_sd vs baro_zscore_x, K-S Statistic: 0.49782145828339375, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs linaccel_x_mean, K-S Statistic: 0.7480317921384491, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs linaccel_y_mean, K-S Statistic: 0.547488449263714, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs linaccel_z_mean, K-S Statistic: 0.32169094318870817, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs linaccel_zscore_x_mean, K-S Statistic: 0.5018213266778532, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs linaccel_zscore_y_mean, K-S Statistic: 0.4628660866622485, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs linaccel_zscore_z_mean, K-S Statistic: 0.5408235686722411, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs time_mergedpost, K-S Statistic: 0.9854904891495933, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_x_max, K-S Statistic: 0.7074455834590636, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_y_max, K-S Statistic: 0.7271958149438091, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_z_max, K-S Statistic: 0.7881150796448531, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_zscore_x_max, K-S Statistic: 0.35919840395849617, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_zscore_y_max, K-S Statistic: 0.3134280045234469, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_zscore_z_max, K-S Statistic: 0.34765131183613046, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_x_min, K-S Statistic: 0.870641153992583, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_y_min, K-S Statistic: 0.8916792396959913, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_z_min, K-S Statistic: 0.903815150617841, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_zscore_x_min, K-S Statistic: 0.7302480044239554, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_zscore_y_min, K-S Statistic: 0.7541178197763497, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_zscore_z_min, K-S Statistic: 0.7215097219572982, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_x_sd, K-S Statistic: 0.8294157184017448, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_y_sd, K-S Statistic: 0.8198508157193418, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_z_sd, K-S Statistic: 0.9023063870988969, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_zscore_x_sd, K-S Statistic: 0.24658783433474052, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_zscore_y_sd, K-S Statistic: 0.2547755722885736, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_zscore_z_sd, K-S Statistic: 0.28388642880842857, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_x_mean, K-S Statistic: 0.8079170133062602, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_y_mean, K-S Statistic: 0.8301677500622776, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_z_mean, K-S Statistic: 0.8618752849494964, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_zscore_x_mean, K-S Statistic: 0.5582963828021016, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_zscore_y_mean, K-S Statistic: 0.5543994977927683, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs gyro_zscore_z_mean, K-S Statistic: 0.5466960123610521, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs time_baro, K-S Statistic: 0.9839488242455008, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_zscore_z_sd vs baro_zscore_x, K-S Statistic: 0.49791546224096034, p-value: 0.0
# Variables: linaccel_x_mean vs linaccel_y_mean, K-S Statistic: 0.43616426251545193, p-value: 0.0
# Variables: linaccel_x_mean vs linaccel_z_mean, K-S Statistic: 0.5299567111775405, p-value: 0.0
# Variables: linaccel_x_mean vs linaccel_zscore_x_mean, K-S Statistic: 0.29888088288516945, p-value: 0.0
# Variables: linaccel_x_mean vs linaccel_zscore_y_mean, K-S Statistic: 0.3235475213506488, p-value: 0.0
# Variables: linaccel_x_mean vs linaccel_zscore_z_mean, K-S Statistic: 0.288455843991032, p-value: 0.0
# Variables: linaccel_x_mean vs time_mergedpost, K-S Statistic: 0.9963197450612671, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_x_max, K-S Statistic: 0.2909798502516956, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_y_max, K-S Statistic: 0.33659057046301655, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_z_max, K-S Statistic: 0.323763730453052, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_zscore_x_max, K-S Statistic: 0.400714870600883, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_zscore_y_max, K-S Statistic: 0.4353670941866263, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_zscore_z_max, K-S Statistic: 0.41078410675206695, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_x_min, K-S Statistic: 0.1693763307435242, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_y_min, K-S Statistic: 0.19989471556752536, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_z_min, K-S Statistic: 0.19433908167533853, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_zscore_x_min, K-S Statistic: 0.4119187267741903, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_zscore_y_min, K-S Statistic: 0.38743650538012314, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_zscore_z_min, K-S Statistic: 0.39239115405555103, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_x_sd, K-S Statistic: 0.5677510023171976, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_y_sd, K-S Statistic: 0.5672856827272429, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_z_sd, K-S Statistic: 0.5667780613563832, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_zscore_x_sd, K-S Statistic: 0.6413474696755822, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_zscore_y_sd, K-S Statistic: 0.6320136757378573, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_zscore_z_sd, K-S Statistic: 0.6584709436811578, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_x_mean, K-S Statistic: 0.1568879049807997, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_y_mean, K-S Statistic: 0.19838125185070293, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_z_mean, K-S Statistic: 0.2303237966318382, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_zscore_x_mean, K-S Statistic: 0.2277446050133743, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_zscore_y_mean, K-S Statistic: 0.2001611591853587, p-value: 0.0
# Variables: linaccel_x_mean vs gyro_zscore_z_mean, K-S Statistic: 0.21689434262502216, p-value: 0.0
# Variables: linaccel_x_mean vs time_baro, K-S Statistic: 0.9947780801571746, p-value: 0.0
# Variables: linaccel_x_mean vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_x_mean vs baro_zscore_x, K-S Statistic: 0.3955780538360665, p-value: 0.0
# Variables: linaccel_y_mean vs linaccel_z_mean, K-S Statistic: 0.37148953970962184, p-value: 0.0
# Variables: linaccel_y_mean vs linaccel_zscore_x_mean, K-S Statistic: 0.33631325878819496, p-value: 0.0
# Variables: linaccel_y_mean vs linaccel_zscore_y_mean, K-S Statistic: 0.29084354451322403, p-value: 0.0
# Variables: linaccel_y_mean vs linaccel_zscore_z_mean, K-S Statistic: 0.3655296887998985, p-value: 0.0
# Variables: linaccel_y_mean vs time_mergedpost, K-S Statistic: 0.9960612341779589, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_x_max, K-S Statistic: 0.3873950093298928, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_y_max, K-S Statistic: 0.4087809096762974, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_z_max, K-S Statistic: 0.4704146044548476, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_zscore_x_max, K-S Statistic: 0.34949324065936793, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_zscore_y_max, K-S Statistic: 0.34889508139788894, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_zscore_z_max, K-S Statistic: 0.34096736405814154, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_x_min, K-S Statistic: 0.5737625554035826, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_y_min, K-S Statistic: 0.5983821918902786, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_z_min, K-S Statistic: 0.6061422185874026, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_zscore_x_min, K-S Statistic: 0.5217723658564551, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_zscore_y_min, K-S Statistic: 0.5137148705126529, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_zscore_z_min, K-S Statistic: 0.5044206880185873, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_x_sd, K-S Statistic: 0.5128056891195119, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_y_sd, K-S Statistic: 0.5041150232424785, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_z_sd, K-S Statistic: 0.5938041991567845, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_zscore_x_sd, K-S Statistic: 0.3049106551532975, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_zscore_y_sd, K-S Statistic: 0.2999619011917578, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_zscore_z_sd, K-S Statistic: 0.26488558460300615, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_x_mean, K-S Statistic: 0.49714462978891416, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_y_mean, K-S Statistic: 0.5218018678586369, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_z_mean, K-S Statistic: 0.5524659588168662, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_zscore_x_mean, K-S Statistic: 0.3223505284876407, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_zscore_y_mean, K-S Statistic: 0.2736532359084357, p-value: 0.0
# Variables: linaccel_y_mean vs gyro_zscore_z_mean, K-S Statistic: 0.3040154656002647, p-value: 0.0
# Variables: linaccel_y_mean vs time_baro, K-S Statistic: 0.9945289696696231, p-value: 0.0
# Variables: linaccel_y_mean vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_y_mean vs baro_zscore_x, K-S Statistic: 0.4131661942967799, p-value: 0.0
# Variables: linaccel_z_mean vs linaccel_zscore_x_mean, K-S Statistic: 0.30248123445997077, p-value: 0.0
# Variables: linaccel_z_mean vs linaccel_zscore_y_mean, K-S Statistic: 0.25722302908952466, p-value: 0.0
# Variables: linaccel_z_mean vs linaccel_zscore_z_mean, K-S Statistic: 0.33451778319867265, p-value: 0.0
# Variables: linaccel_z_mean vs time_mergedpost, K-S Statistic: 0.9942986599735849, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_x_max, K-S Statistic: 0.5008295849255253, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_y_max, K-S Statistic: 0.5158749183340618, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_z_max, K-S Statistic: 0.5758259422721697, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_zscore_x_max, K-S Statistic: 0.24211895500334601, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_zscore_y_max, K-S Statistic: 0.23068113535642054, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_zscore_z_max, K-S Statistic: 0.22636219597837204, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_x_min, K-S Statistic: 0.6427332590702068, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_y_min, K-S Statistic: 0.6634094295369835, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_z_min, K-S Statistic: 0.6758085515400198, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_zscore_x_min, K-S Statistic: 0.5110204937724608, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_zscore_y_min, K-S Statistic: 0.5275620835670721, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_zscore_z_min, K-S Statistic: 0.4995821829277879, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_x_sd, K-S Statistic: 0.6137565391502982, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_y_sd, K-S Statistic: 0.6032750978816208, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_z_sd, K-S Statistic: 0.6764383780557162, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_zscore_x_sd, K-S Statistic: 0.20115545190677614, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_zscore_y_sd, K-S Statistic: 0.2004586536056002, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_zscore_z_sd, K-S Statistic: 0.20387553770796585, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_x_mean, K-S Statistic: 0.5865987958093036, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_y_mean, K-S Statistic: 0.6059448102765127, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_z_mean, K-S Statistic: 0.637332731708005, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_zscore_x_mean, K-S Statistic: 0.3301283647850435, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_zscore_y_mean, K-S Statistic: 0.3308775481941189, p-value: 0.0
# Variables: linaccel_z_mean vs gyro_zscore_z_mean, K-S Statistic: 0.3189540993213401, p-value: 0.0
# Variables: linaccel_z_mean vs time_baro, K-S Statistic: 0.9927522948716141, p-value: 0.0
# Variables: linaccel_z_mean vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_z_mean vs baro_zscore_x, K-S Statistic: 0.38609775471547353, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs time_mergedpost, K-S Statistic: 0.9838595204858124, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_x_max, K-S Statistic: 0.35852639396118574, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_y_max, K-S Statistic: 0.37116052585813863, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_z_max, K-S Statistic: 0.38631866401575504, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_zscore_x_max, K-S Statistic: 0.18475744220017437, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_zscore_y_max, K-S Statistic: 0.23994054160908307, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_zscore_z_max, K-S Statistic: 0.18963553616571946, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_x_min, K-S Statistic: 0.3830003243136536, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_y_min, K-S Statistic: 0.39858618047819816, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_z_min, K-S Statistic: 0.4130016873710384, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_zscore_x_min, K-S Statistic: 0.23001847898062266, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_zscore_y_min, K-S Statistic: 0.258043045204741, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_zscore_z_min, K-S Statistic: 0.22285477446267532, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_x_sd, K-S Statistic: 0.48561504439336894, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_y_sd, K-S Statistic: 0.48557274261246397, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_z_sd, K-S Statistic: 0.485544541425194, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_zscore_x_sd, K-S Statistic: 0.48960214123729323, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_zscore_y_sd, K-S Statistic: 0.48910459698868136, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_zscore_z_sd, K-S Statistic: 0.49074972781627557, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_x_mean, K-S Statistic: 0.34592046325150294, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_y_mean, K-S Statistic: 0.35890240979145227, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_z_mean, K-S Statistic: 0.387695821994106, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_zscore_x_mean, K-S Statistic: 0.0832503336303535, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_zscore_y_mean, K-S Statistic: 0.10671564606957629, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs gyro_zscore_z_mean, K-S Statistic: 0.08604852260073226, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs time_baro, K-S Statistic: 0.982331956175355, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_zscore_x_mean vs baro_zscore_x, K-S Statistic: 0.1808025117857462, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs linaccel_zscore_z_mean, K-S Statistic: 0.07965425344407007, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs time_mergedpost, K-S Statistic: 0.9845222483866571, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_x_max, K-S Statistic: 0.3129438749371348, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_y_max, K-S Statistic: 0.32598692404950247, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_z_max, K-S Statistic: 0.37039439360397075, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_zscore_x_max, K-S Statistic: 0.13924064078456744, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_zscore_y_max, K-S Statistic: 0.19475216248032076, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_zscore_z_max, K-S Statistic: 0.14449953594010997, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_x_min, K-S Statistic: 0.4174198733766691, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_y_min, K-S Statistic: 0.43441108870683454, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_z_min, K-S Statistic: 0.44838477699911167, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_zscore_x_min, K-S Statistic: 0.26765486095395286, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_zscore_y_min, K-S Statistic: 0.2935200075361244, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_zscore_z_min, K-S Statistic: 0.25982685375681935, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_x_sd, K-S Statistic: 0.44343546863322947, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_y_sd, K-S Statistic: 0.44341196764383783, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_z_sd, K-S Statistic: 0.4551295609545162, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_zscore_x_sd, K-S Statistic: 0.44776583995018876, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_zscore_y_sd, K-S Statistic: 0.44722883617193476, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_zscore_z_sd, K-S Statistic: 0.44925911253495565, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_x_mean, K-S Statistic: 0.3746574730796167, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_y_mean, K-S Statistic: 0.3896793054987615, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_z_mean, K-S Statistic: 0.41948796044313463, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_zscore_x_mean, K-S Statistic: 0.10871456037009519, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_zscore_y_mean, K-S Statistic: 0.1257009208610037, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs gyro_zscore_z_mean, K-S Statistic: 0.10724211630169, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs time_baro, K-S Statistic: 0.982985283680443, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_zscore_y_mean vs baro_zscore_x, K-S Statistic: 0.2012436723586063, p-value: 0.0
# Variables: linaccel_zscore_z_mean vs time_mergedpost, K-S Statistic: 0.9834788044576677, p-value: 0.0
# Variables: linaccel_zscore_z_mean vs gyro_x_max, K-S Statistic: 0.3886499621634071, p-value: 0.0
# Variables: linaccel_zscore_z_mean vs gyro_y_max, K-S Statistic: 0.40290096213050575, p-value: 0.0
# Variables: linaccel_zscore_z_mean vs gyro_z_max, K-S Statistic: 0.4175232777299924, p-value: 0.0
# Variables: linaccel_zscore_z_mean vs gyro_zscore_x_max, K-S Statistic: 0.21521908318401656, p-value: 0.0
# Variables: linaccel_zscore_z_mean vs gyro_zscore_y_max, K-S Statistic: 0.27228045179919874, p-value: 0.0
# Variables: linaccel_zscore_z_mean vs gyro_zscore_z_max, K-S Statistic: 0.2212179279264615, p-value: 0.0
# Variables: linaccel_zscore_z_mean vs gyro_x_min, K-S Statistic: 0.3430063405669379, p-value: 0.0
# Variables: linaccel_zscore_z_mean vs gyro_y_min, K-S Statistic: 0.35848409218028077, p-value: 0.0
# ...
# Variables: gyro_zscore_z_mean vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: gyro_zscore_z_mean vs baro_zscore_x, K-S Statistic: 0.2207303487055533, p-value: 0.0
# Variables: time_baro vs baro_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: time_baro vs baro_zscore_x, K-S Statistic: 0.9870697556367123, p-value: 0.0
# Variables: baro_x vs baro_zscore_x, K-S Statistic: 1.0, p-value: 0.0
# Variables: linaccel_zscore_y_min vs linaccel_zscore_z_min, K-S Statistic: 0.05857856615763524, p-value: 9.57029e-318
# Variables: accel_x_mean vs accel_zscore_z_mean, K-S Statistic: 0.057643226779847456, p-value: 1.098178095801052e-307
# Variables: accel_zscore_y_max vs accel_zscore_z_mean, K-S Statistic: 0.05701340026415114, p-value: 5.2854007638159875e-301
# Variables: accel_zscore_y_min vs accel_zscore_x_mean, K-S Statistic: 0.055791348815785125, p-value: 3.0125093307452943e-288
# Variables: accel_zscore_x_min vs accel_zscore_inclination_mean, K-S Statistic: 0.055490536151571956, p-value: 3.76985112823174e-285
# Variables: accel_zscore_x_max vs accel_zscore_y_mean, K-S Statistic: 0.054357788462894296, p-value: 1.2282883161439437e-273
# Variables: accel_zscore_x_max vs accel_zscore_z_mean, K-S Statistic: 0.054009973819897805, p-value: 3.772535240564512e-270
# Variables: accel_zscore_x_max vs accel_zscore_x_mean, K-S Statistic: 0.053699760759927995, p-value: 4.656101385963753e-267
# Variables: accel_zscore_inclination_max vs accel_zscore_x_mean, K-S Statistic: 0.05293832870363846, p-value: 1.5145803652534602e-259
# Variables: accel_zscore_x_min vs accel_zscore_x_mean, K-S Statistic: 0.052858425339706805, p-value: 9.170265272272688e-259
# Variables: accel_x_sd vs linaccel_y_sd, K-S Statistic: 0.05275032078850522, p-value: 1.0438019766502062e-257
# Variables: linaccel_zscore_x_max vs linaccel_zscore_y_max, K-S Statistic: 0.052247399615523826, p-value: 8.015185894052433e-253
# Variables: gyro_zscore_x_mean vs gyro_zscore_y_mean, K-S Statistic: 0.05291051343797448, p-value: 4.967826610899423e-252
# Variables: gyro_zscore_y_max vs gyro_zscore_z_max, K-S Statistic: 0.05164843666889102, p-value: 3.654135188663128e-240
# Variables: gyro_x_max vs gyro_y_max, K-S Statistic: 0.05014641116391, p-value: 6.386693214341644e-233
# Variables: accel_zscore_inclination_max vs accel_zscore_z_mean, K-S Statistic: 0.04949778385670034, p-value: 6.080859323497708e-227
# Variables: accel_zscore_inclination_mean vs baro_zscore_x, K-S Statistic: 0.04852014269800761, p-value: 4.445674334611735e-218
# Variables: accel_zscore_inclination_max vs accel_zscore_inclination_mean, K-S Statistic: 0.0481770282528895, p-value: 5.210097323522029e-215
# Variables: accel_zscore_inclination_min vs accel_zscore_inclination_mean, K-S Statistic: 0.04788091578655462, p-value: 2.227469830213577e-212
# Variables: accel_inclination_max vs accel_inclination_min, K-S Statistic: 0.04746729837326147, p-value: 9.899304960258158e-209
# Variables: accel_zscore_y_max vs accel_zscore_y_mean, K-S Statistic: 0.046973777596036825, p-value: 2.0257892724533972e-204
# Variables: accel_x_sd vs accel_y_sd, K-S Statistic: 0.04695967700240189, p-value: 2.6859756143533686e-204
# Variables: accel_y_max vs accel_y_min, K-S Statistic: 0.04629694910155713, p-value: 1.3976609313904682e-198
# Variables: accel_zscore_z_max vs accel_zscore_inclination_max, K-S Statistic: 0.04591153287553407, p-value: 2.706081733973247e-195
# Variables: accel_zscore_y_mean vs baro_zscore_x, K-S Statistic: 0.045864530896750744, p-value: 6.78115801893107e-195
# Variables: accel_zscore_y_min vs accel_zscore_y_mean, K-S Statistic: 0.04583632970948076, p-value: 1.1762106995930938e-194
# Variables: linaccel_zscore_x_mean vs linaccel_zscore_y_mean, K-S Statistic: 0.04567652298161756, p-value: 2.6488765125099188e-193
# Variables: accel_zscore_x_mean vs baro_zscore_x, K-S Statistic: 0.04388104739209531, p-value: 1.969672013447024e-178
# Variables: accel_zscore_z_avg_weigh_freq vs accel_zscore_inclination_avg_weigh_freq, K-S Statistic: 0.042931607420672396, p-value: 8.257740158433826e-171
# Variables: gyro_x_mean vs gyro_y_mean, K-S Statistic: 0.04268249693312093, p-value: 7.747457728970501e-169
# Variables: accel_zscore_y_avg_weigh_freq vs accel_zscore_z_avg_weigh_freq, K-S Statistic: 0.04184116151289971, p-value: 2.919730833611678e-162
# Variables: linaccel_x_sd vs linaccel_y_sd, K-S Statistic: 0.041263037173865036, p-value: 8.094130766203024e-158
# Variables: gyro_zscore_x_sd vs gyro_zscore_z_sd, K-S Statistic: 0.04183711956364067, p-value: 1.057801430764489e-157
# Variables: gyro_zscore_y_sd vs gyro_zscore_z_sd, K-S Statistic: 0.041237512209746474, p-value: 3.1752786077794105e-153
# Variables: accel_z_dominant_freq vs accel_zscore_x_dominant_freq, K-S Statistic: 0.040642611053925415, p-value: 4.0477867440887074e-153
# Variables: accel_y_dominant_freq vs accel_zscore_x_dominant_freq, K-S Statistic: 0.04061911006453378, p-value: 6.078696585856563e-153
# Variables: accel_inclination_dominant_freq vs accel_zscore_x_dominant_freq, K-S Statistic: 0.04061440986665543, p-value: 6.593511384243404e-153
# Variables: linaccel_zscore_x_mean vs linaccel_zscore_z_mean, K-S Statistic: 0.040243094234267196, p-value: 3.9389909097876185e-150
# Variables: accel_y_avg_weigh_freq vs accel_z_avg_weigh_freq, K-S Statistic: 0.03985767800824416, p-value: 2.8188640606251175e-147
# Variables: accel_zscore_x_max vs accel_zscore_z_max, K-S Statistic: 0.03977307444643419, p-value: 1.18312631770275e-146
# Variables: accel_zscore_y_max vs accel_zscore_z_max, K-S Statistic: 0.039552165146152646, p-value: 4.936189508480141e-145
# Variables: accel_zscore_y_min vs accel_zscore_inclination_mean, K-S Statistic: 0.03889883764106472, p-value: 2.7079353044918753e-140
# Variables: accel_x_avg_weigh_freq vs accel_zscore_x_avg_weigh_freq, K-S Statistic: 0.03872493031956645, p-value: 4.795617812187214e-139
# Variables: linaccel_zscore_x_min vs linaccel_zscore_z_min, K-S Statistic: 0.03755928124574048, p-value: 7.99171563876642e-131
# Variables: accel_zscore_inclination_max vs accel_zscore_y_mean, K-S Statistic: 0.03731017075818899, p-value: 4.237314896660129e-129
# Variables: accel_y_sd vs linaccel_x_sd, K-S Statistic: 0.03651113711887266, p-value: 1.2045400387103205e-123
# Variables: accel_x_max vs accel_x_mean, K-S Statistic: 0.03622912524617289, p-value: 9.493958444631177e-122
# Variables: accel_zscore_y_min vs accel_zscore_z_min, K-S Statistic: 0.036182123267389565, p-value: 1.959387254901816e-121
# Variables: accel_z_min vs accel_z_mean, K-S Statistic: 0.035975314560743016, p-value: 4.697024097342395e-120
# Variables: gyro_zscore_y_min vs gyro_zscore_z_min, K-S Statistic: 0.03638262686047533, p-value: 2.3481609933389942e-119
# Variables: accel_z_dominant_freq vs accel_zscore_inclination_dominant_freq, K-S Statistic: 0.03573560446894819, p-value: 1.8243848274113178e-118
# Variables: accel_y_dominant_freq vs accel_zscore_inclination_dominant_freq, K-S Statistic: 0.035712103479556556, p-value: 2.6082969014080123e-118
# Variables: accel_inclination_dominant_freq vs accel_zscore_inclination_dominant_freq, K-S Statistic: 0.03570740328167821, p-value: 2.801514481652328e-118
# Variables: gyro_x_min vs gyro_y_min, K-S Statistic: 0.035660401302894884, p-value: 5.721717544308315e-118
# Variables: gyro_zscore_y_mean vs gyro_zscore_z_mean, K-S Statistic: 0.03595226351776093, p-value: 1.473591547940148e-116
# Variables: accel_z_dominant_freq vs accel_zscore_y_dominant_freq, K-S Statistic: 0.03475326311237703, p-value: 4.6025207566612e-112
# Variables: accel_y_dominant_freq vs accel_zscore_y_dominant_freq, K-S Statistic: 0.0347297621229854, p-value: 6.515729261446143e-112
# Variables: accel_inclination_dominant_freq vs accel_zscore_y_dominant_freq, K-S Statistic: 0.03472506192510705, p-value: 6.984643076564626e-112
# Variables: accel_x_min vs accel_x_mean, K-S Statistic: 0.034518253218460526, p-value: 1.472544079240785e-110
# Variables: accel_x_dominant_freq vs accel_zscore_z_dominant_freq, K-S Statistic: 0.034109336003045665, p-value: 5.787969301500158e-108
# Variables: accel_z_max vs accel_z_mean, K-S Statistic: 0.03379912294307591, p-value: 5.129688313325286e-106
# Variables: gyro_y_mean vs gyro_z_mean, K-S Statistic: 0.03250186832865665, p-value: 4.586550380795587e-98
# Variables: linaccel_zscore_x_max vs linaccel_zscore_z_max, K-S Statistic: 0.032454866349873324, p-value: 8.784837975232617e-98
# Variables: gyro_zscore_x_min vs gyro_zscore_y_min, K-S Statistic: 0.032519027862399796, p-value: 1.9652737425868306e-95
# Variables: linaccel_zscore_x_min vs linaccel_zscore_y_min, K-S Statistic: 0.027970877573945896, p-value: 9.78345863380382e-73
# Variables: accel_y_avg_weigh_freq vs accel_inclination_avg_weigh_freq, K-S Statistic: 0.027200045121899635, p-value: 8.346976353288723e-69
# Variables: gyro_zscore_x_min vs gyro_zscore_z_min, K-S Statistic: 0.027248285799943928, p-value: 3.9712242921348336e-67
# Variables: accel_zscore_x_min vs accel_zscore_z_min, K-S Statistic: 0.026264705744111883, p-value: 3.498706064892808e-64
# Variables: accel_zscore_x_avg_weigh_freq vs accel_zscore_z_avg_weigh_freq, K-S Statistic: 0.025794685956278762, p-value: 6.391755962487059e-62
# Variables: accel_zscore_x_mean vs accel_zscore_z_mean, K-S Statistic: 0.025221261815122437, p-value: 3.2327741501355002e-59
# Variables: accel_inclination_max vs accel_inclination_mean, K-S Statistic: 0.02513665825331246, p-value: 8.005181487113302e-59
# Variables: accel_x_dominant_freq vs accel_z_dominant_freq, K-S Statistic: 0.02506145508725921, p-value: 1.7877242412124494e-58
# Variables: accel_x_dominant_freq vs accel_y_dominant_freq, K-S Statistic: 0.025037954097867576, p-value: 2.2968172340781717e-58
# Variables: accel_x_dominant_freq vs accel_inclination_dominant_freq, K-S Statistic: 0.025033253899989227, p-value: 2.414789964028647e-58
# Variables: accel_zscore_z_min vs accel_zscore_inclination_min, K-S Statistic: 0.02498155172332761, p-value: 4.1868929366197386e-58
# Variables: accel_y_max vs accel_y_mean, K-S Statistic: 0.024614936288817835, p-value: 2.006899453474936e-56
# Variables: accel_zscore_x_min vs accel_zscore_y_min, K-S Statistic: 0.024572634507912805, p-value: 3.1249659332457453e-56
# Variables: accel_zscore_y_dominant_freq vs accel_zscore_z_dominant_freq, K-S Statistic: 0.024417527977927844, p-value: 1.574656992823364e-55
# Variables: accel_zscore_z_mean vs accel_zscore_inclination_mean, K-S Statistic: 0.02355269156831502, p-value: 1.0757229873036917e-51
# Variables: accel_zscore_z_dominant_freq vs accel_zscore_inclination_dominant_freq, K-S Statistic: 0.023435186621356685, p-value: 3.4835386834348067e-51
# Variables: accel_y_min vs accel_y_mean, K-S Statistic: 0.023355283257425086, p-value: 7.719334126094143e-51
# Variables: accel_inclination_min vs accel_inclination_mean, K-S Statistic: 0.023331782268033452, p-value: 9.749676302166704e-51
# Variables: accel_zscore_y_sd vs accel_zscore_inclination_sd, K-S Statistic: 0.022274237745409098, p-value: 2.797349859836347e-46
# Variables: accel_zscore_y_mean vs accel_zscore_z_mean, K-S Statistic: 0.021884121321507632, p-value: 1.0938197042805651e-44
# Variables: accel_zscore_x_max vs accel_zscore_inclination_max, K-S Statistic: 0.02154100687638949, p-value: 2.606470402589364e-43
# Variables: accel_zscore_x_mean vs accel_zscore_inclination_mean, K-S Statistic: 0.0214470029188229, p-value: 6.1594693225559314e-43
# Variables: accel_zscore_x_avg_weigh_freq vs accel_zscore_inclination_avg_weigh_freq, K-S Statistic: 0.02090648016281485, p-value: 8.042739119718431e-41
# Variables: accel_x_avg_weigh_freq vs accel_zscore_y_avg_weigh_freq, K-S Statistic: 0.020337756219536846, p-value: 1.183949889360065e-38
# Variables: linaccel_zscore_x_sd vs linaccel_zscore_z_sd, K-S Statistic: 0.020318955428023533, p-value: 1.3930900981059072e-38
# Variables: accel_x_avg_weigh_freq vs accel_zscore_inclination_avg_weigh_freq, K-S Statistic: 0.020098046127741992, p-value: 9.314783701277571e-38
# Variables: accel_zscore_x_min vs accel_zscore_inclination_min, K-S Statistic: 0.01933191387357408, p-value: 5.76906088579945e-35
# Variables: accel_zscore_x_avg_weigh_freq vs accel_zscore_y_avg_weigh_freq, K-S Statistic: 0.019017000615725865, p-value: 7.537677080012175e-34
# Variables: gyro_zscore_x_max vs gyro_zscore_z_max, K-S Statistic: 0.01902786239978338, p-value: 5.96116264737542e-33
# Variables: accel_zscore_x_dominant_freq vs accel_zscore_z_dominant_freq, K-S Statistic: 0.01852818003637946, p-value: 3.7447467416399214e-32
# Variables: gyro_zscore_x_mean vs gyro_zscore_z_mean, K-S Statistic: 0.01851529482306752, p-value: 3.191933421801829e-31
# Variables: accel_zscore_x_mean vs accel_zscore_y_mean, K-S Statistic: 0.018011158269763072, p-value: 2.0863686134321025e-30
# Variables: accel_z_avg_weigh_freq vs accel_inclination_avg_weigh_freq, K-S Statistic: 0.017409532941336847, p-value: 1.9446968981207992e-28
# Variables: gyro_x_sd vs gyro_y_sd, K-S Statistic: 0.017052317902583713, p-value: 2.670292070495109e-27
# Variables: gyro_zscore_x_sd vs gyro_zscore_y_sd, K-S Statistic: 0.016803512538563464, p-value: 8.614193444064443e-26
# Variables: accel_x_dominant_freq vs accel_zscore_x_dominant_freq, K-S Statistic: 0.015581155966666205, p-value: 7.302726816931255e-23
# Variables: accel_zscore_y_min vs accel_zscore_inclination_min, K-S Statistic: 0.01552475359212624, p-value: 1.0607846288555628e-22
# Variables: accel_zscore_y_mean vs accel_zscore_inclination_mean, K-S Statistic: 0.013550670483227334, p-value: 2.138591520369094e-17
# Variables: accel_x_sd vs linaccel_x_sd, K-S Statistic: 0.013456666525660743, p-value: 3.670753593488958e-17
# Variables: linaccel_zscore_y_sd vs linaccel_zscore_z_sd, K-S Statistic: 0.013033648716610974, p-value: 3.984421355165396e-16
# Variables: accel_zscore_y_max vs accel_zscore_inclination_max, K-S Statistic: 0.011571887176450135, p-value: 8.401395520071101e-13
# Variables: accel_zscore_x_max vs accel_zscore_y_max, K-S Statistic: 0.011557786582815144, p-value: 9.005179413889861e-13
# Variables: linaccel_zscore_x_sd vs linaccel_zscore_y_sd, K-S Statistic: 0.010895058681970549, p-value: 2.1363073079057258e-11
# Variables: accel_x_dominant_freq vs accel_zscore_inclination_dominant_freq, K-S Statistic: 0.01067414938168898, p-value: 5.888635932128808e-11
# Variables: accel_z_sd vs linaccel_z_sd, K-S Statistic: 0.009903316929642747, p-value: 1.7215218678698878e-09
# Variables: accel_x_dominant_freq vs accel_zscore_y_dominant_freq, K-S Statistic: 0.00969180802511782, p-value: 4.1585314218709116e-09
# Variables: accel_y_sd vs linaccel_y_sd, K-S Statistic: 0.008530859149170178, p-value: 3.750543704026605e-07
# Variables: accel_zscore_x_dominant_freq vs accel_zscore_y_dominant_freq, K-S Statistic: 0.005889347941548384, p-value: 0.0012431101678088666
# Variables: accel_zscore_x_dominant_freq vs accel_zscore_inclination_dominant_freq, K-S Statistic: 0.005250121030095367, p-value: 0.005657720396923773
# Variables: accel_zscore_y_avg_weigh_freq vs accel_zscore_inclination_avg_weigh_freq, K-S Statistic: 0.0026791127906484746, p-value: 0.42914536221214505
# Variables: time_accel vs time_baro, K-S Statistic: 0.0016685702468073906, p-value: 0.928015877562487
# Variables: time_linaccel vs time_baro, K-S Statistic: 0.0016685702468073906, p-value: 0.928015877562487
# Variables: time_mergedpost vs time_baro, K-S Statistic: 0.0016685702468073906, p-value: 0.928015877562487
# Variables: accel_zscore_y_dominant_freq vs accel_zscore_inclination_dominant_freq, K-S Statistic: 0.0009823413565711592, p-value: 0.9999510339709037
# Variables: time_accel vs time_linaccel, K-S Statistic: 0.00012220514483659762, p-value: 1.0
# Variables: time_accel vs time_mergedpost, K-S Statistic: 0.00011750494695826695, p-value: 1.0
# Variables: accel_y_dominant_freq vs accel_z_dominant_freq, K-S Statistic: 2.350098939163381e-05, p-value: 1.0
# Variables: accel_y_dominant_freq vs accel_inclination_dominant_freq, K-S Statistic: 4.700197878348966e-06, p-value: 1.0
# Variables: accel_z_dominant_freq vs accel_inclination_dominant_freq, K-S Statistic: 2.8201187269982775e-05, p-value: 1.0
# Variables: time_linaccel vs time_mergedpost, K-S Statistic: 2.8201187270093797e-05, p-value: 1.0

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5ea8f536-739f-4c50-806e-84490cb7d5e0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
